# %%
import pandas as pd

# %%
from pathlib import Path

# %%
str(Path("../").resolve())
# Out:
# 'C:\\sprint5'

# %%
import os
os.chdir(str(Path("../")))

# %%
import src.preprocessing as f

# %%
import src.simulando.analistando as sa

# %%
df = pd.read_csv(Path("Data/vehicles.csv"))
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = pd.read_csv(Path("Data/vehicles.csv"))
#       2 df.head()
#
# File c:\Users\misao\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
print(len(df))
print(df['days_listed'].max())
print(df['days_listed'].min())
# Out:
# 51525
# 271
# 0

# %%
df = f.remover_outliers(df, 'days_listed')

# %%
print(len(df))
print(df['days_listed'].max())
print(df['days_listed'].min())
# Out:
# 49120
# 95
# 0

# %%
sa.funcao()
# Out:
# vamos comecar de novo

# %%
import plotly.express as px

# %%
px.histogram(df, x = 'days_listed')
